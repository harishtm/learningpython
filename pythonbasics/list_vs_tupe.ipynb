# %%
# list vs tuple

# %%
from IPython.display import Image
Image(filename='tuples-vs-lists.jpg')

# %%
Image(filename='tuplevslist1.jpeg')

# %%
# https://techvidvan.com/tutorials/python-tuples-vs-lists/
# https://techvidvan.com/tutorials/python-generators/
# https://www.sanfoundry.com/1000-python-questions-answers/

# %%
# Python negative indexing
